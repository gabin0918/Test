# %% [markdown]
# <a href="https://colab.research.google.com/github/gabin0918/Test/blob/main/pandas/dane_gieldowe_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as p

# %%
#zaladowanie danych
def fetch_financial_data(company='AMZN'):

  import pandas_datareader.data as web
  return web.DataReader(name=company,data_source='stooq')

df=fetch_financial_data()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1256 entries, 2024-08-05 to 2019-08-08
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1256 non-null   float64
#  1   High    1256 non-null   float64
#  2   Low     1256 non-null   float64
#  3   Close   1256 non-null   float64
#  4   Volume  1256 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB

# %%
df
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 2024-08-05  154.2100  162.9600  151.6100  161.0200   83149437
# 2024-08-02  166.7500  168.7700  160.5500  167.9000  141448365
# 2024-08-01  189.2850  190.6000  181.8700  184.0700   70435635
# 2024-07-31  185.0500  187.9400  184.4600  186.9800   41667326
# 2024-07-30  184.7200  185.8600  179.3800  181.7100   39508574
# ...              ...       ...       ...       ...        ...
# 2019-08-14   89.6505   89.7825   87.8610   88.1480   97872980
# 2019-08-13   89.1500   91.5870   89.0000   91.2170   81500420
# 2019-08-12   89.7995   90.0490   88.8500   89.2460   58109960
# 2019-08-09   91.4475   91.5545   90.1110   90.3790   57595400
# 2019-08-08   90.3000   91.7130   89.9055   91.6445   74024840
#
# [1256 rows x 5 columns]

# %%
df.head()
# Out:
#                Open    High     Low   Close     Volume
# Date
# 2024-08-05  154.210  162.96  151.61  161.02   83149437
# 2024-08-02  166.750  168.77  160.55  167.90  141448365
# 2024-08-01  189.285  190.60  181.87  184.07   70435635
# 2024-07-31  185.050  187.94  184.46  186.98   41667326
# 2024-07-30  184.720  185.86  179.38  181.71   39508574

# %%
df.tail()
# Out:
#                Open     High      Low    Close    Volume
# Date
# 2019-08-14  89.6505  89.7825  87.8610  88.1480  97872980
# 2019-08-13  89.1500  91.5870  89.0000  91.2170  81500420
# 2019-08-12  89.7995  90.0490  88.8500  89.2460  58109960
# 2019-08-09  91.4475  91.5545  90.1110  90.3790  57595400
# 2019-08-08  90.3000  91.7130  89.9055  91.6445  74024840

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
df.columns=[col.lower() for col in df.columns]

# %%
df.head()
# Out:
#                open    high     low   close     volume
# Date
# 2024-08-05  154.210  162.96  151.61  161.02   83149437
# 2024-08-02  166.750  168.77  160.55  167.90  141448365
# 2024-08-01  189.285  190.60  181.87  184.07   70435635
# 2024-07-31  185.050  187.94  184.46  186.98   41667326
# 2024-07-30  184.720  185.86  179.38  181.71   39508574

# %%
df.describe().T
# Out:
#          count          mean           std           min           25%  \
# open    1256.0  1.381579e+02  3.173974e+01  8.207550e+01  1.080675e+02
# high    1256.0  1.398419e+02  3.191543e+01  8.348000e+01  1.105415e+02
# low     1256.0  1.363622e+02  3.145416e+01  8.130160e+01  1.063167e+02
# close   1256.0  1.381219e+02  3.165726e+01  8.182000e+01  1.079460e+02
# volume  1256.0  7.048247e+07  3.319654e+07  1.762674e+07  4.866071e+07
#
#                  50%           75%           max
# open    1.439075e+02  1.648510e+02  2.000900e+02
# high    1.458990e+02  1.663550e+02  2.012000e+02
# low     1.414950e+02  1.629592e+02  1.990450e+02
# close   1.444325e+02  1.646985e+02  2.000000e+02
# volume  6.196110e+07  8.264252e+07  3.113457e+08

# %%
df = df.head(10)

# %%
df
# Out:
#                open      high     low   close     volume
# Date
# 2024-08-05  154.210  162.9600  151.61  161.02   83149437
# 2024-08-02  166.750  168.7700  160.55  167.90  141448365
# 2024-08-01  189.285  190.6000  181.87  184.07   70435635
# 2024-07-31  185.050  187.9400  184.46  186.98   41667326
# 2024-07-30  184.720  185.8600  179.38  181.71   39508574
# 2024-07-29  183.840  184.7500  182.38  183.20   33270123
# 2024-07-26  180.390  183.1900  180.24  182.50   29505964
# 2024-07-25  182.910  183.8958  176.80  179.85   44464163
# 2024-07-24  183.200  185.4500  180.41  180.83   41532360
# 2024-07-23  184.100  189.3900  183.56  186.41   47537670

# %%
df['open']
# Out:
# Date
# 2024-08-05    154.210
# 2024-08-02    166.750
# 2024-08-01    189.285
# 2024-07-31    185.050
# 2024-07-30    184.720
# 2024-07-29    183.840
# 2024-07-26    180.390
# 2024-07-25    182.910
# 2024-07-24    183.200
# 2024-07-23    184.100
# Name: open, dtype: float64

# %%
df.open
# Out:
# Date
# 2024-08-05    154.210
# 2024-08-02    166.750
# 2024-08-01    189.285
# 2024-07-31    185.050
# 2024-07-30    184.720
# 2024-07-29    183.840
# 2024-07-26    180.390
# 2024-07-25    182.910
# 2024-07-24    183.200
# 2024-07-23    184.100
# Name: open, dtype: float64

# %%
df[['open','close']]
# Out:
#                open   close
# Date
# 2024-08-05  154.210  161.02
# 2024-08-02  166.750  167.90
# 2024-08-01  189.285  184.07
# 2024-07-31  185.050  186.98
# 2024-07-30  184.720  181.71
# 2024-07-29  183.840  183.20
# 2024-07-26  180.390  182.50
# 2024-07-25  182.910  179.85
# 2024-07-24  183.200  180.83
# 2024-07-23  184.100  186.41

# %%
df.iloc[:,[0,3]]
# Out:
#                open   close
# Date
# 2024-08-05  154.210  161.02
# 2024-08-02  166.750  167.90
# 2024-08-01  189.285  184.07
# 2024-07-31  185.050  186.98
# 2024-07-30  184.720  181.71
# 2024-07-29  183.840  183.20
# 2024-07-26  180.390  182.50
# 2024-07-25  182.910  179.85
# 2024-07-24  183.200  180.83
# 2024-07-23  184.100  186.41

# %%
df.iloc[:,3:5]
# Out:
#              close     volume
# Date
# 2024-08-05  161.02   83149437
# 2024-08-02  167.90  141448365
# 2024-08-01  184.07   70435635
# 2024-07-31  186.98   41667326
# 2024-07-30  181.71   39508574
# 2024-07-29  183.20   33270123
# 2024-07-26  182.50   29505964
# 2024-07-25  179.85   44464163
# 2024-07-24  180.83   41532360
# 2024-07-23  186.41   47537670

# %%
df.iloc[:,[-1]]
# Out:
#                volume
# Date
# 2024-08-05   83149437
# 2024-08-02  141448365
# 2024-08-01   70435635
# 2024-07-31   41667326
# 2024-07-30   39508574
# 2024-07-29   33270123
# 2024-07-26   29505964
# 2024-07-25   44464163
# 2024-07-24   41532360
# 2024-07-23   47537670

# %%
df.iloc[0]
# Out:
# open           154.21
# high           162.96
# low            151.61
# close          161.02
# volume    83149437.00
# Name: 2024-08-05 00:00:00, dtype: float64

# %%
df.iloc[:-3]
# Out:
#                open    high     low   close     volume
# Date
# 2024-08-05  154.210  162.96  151.61  161.02   83149437
# 2024-08-02  166.750  168.77  160.55  167.90  141448365
# 2024-08-01  189.285  190.60  181.87  184.07   70435635
# 2024-07-31  185.050  187.94  184.46  186.98   41667326
# 2024-07-30  184.720  185.86  179.38  181.71   39508574
# 2024-07-29  183.840  184.75  182.38  183.20   33270123
# 2024-07-26  180.390  183.19  180.24  182.50   29505964

# %%
df
# Out:
#                open      high     low   close     volume
# Date
# 2024-08-05  154.210  162.9600  151.61  161.02   83149437
# 2024-08-02  166.750  168.7700  160.55  167.90  141448365
# 2024-08-01  189.285  190.6000  181.87  184.07   70435635
# 2024-07-31  185.050  187.9400  184.46  186.98   41667326
# 2024-07-30  184.720  185.8600  179.38  181.71   39508574
# 2024-07-29  183.840  184.7500  182.38  183.20   33270123
# 2024-07-26  180.390  183.1900  180.24  182.50   29505964
# 2024-07-25  182.910  183.8958  176.80  179.85   44464163
# 2024-07-24  183.200  185.4500  180.41  180.83   41532360
# 2024-07-23  184.100  189.3900  183.56  186.41   47537670

# %%
df.loc['2024-07-29' : '2024-08-02']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-2923d6b028c1> in <cell line: 1>()
# ----> 1 df.loc['2024-07-29' : '2024-08-02']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1151
#    1152             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153             return self._getitem_axis(maybe_callable, axis=axis)
#    1154
#    1155     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1371         if isinstance(key, slice):
#    1372             self._validate_key(key, axis)
# -> 1373             return self._get_slice_axis(key, axis=axis)
#    1374         elif com.is_bool_indexer(key):
#    1375             return self._getbool_axis(key, axis=axis)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1403
#    1404         labels = obj._get_axis(axis)
# -> 1405         indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1406
#    1407         if isinstance(indexer, slice):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/datetimes.py in slice_indexer(self, start, end, step)
#     696
#     697         if not in_index:
# --> 698             raise KeyError(
#     699                 "Value based partial slicing on non-monotonic DatetimeIndexes "
#     700                 "with non-existing keys is not allowed.",
#
# KeyError: 'Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is not allowed.'
